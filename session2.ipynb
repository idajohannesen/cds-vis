# %% [markdown]
# # Session 3.1 - Defining functions

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## Defining functions in Python

# %%
#defining own function called hello
# the parameters or the argument that a function takes goes inside the parentheses
def hello():
    print("Hello, world!")

# %%
hello()
# Out:
# Hello, world!

# %%
def hello(name):
    print("Hello, " + name + "!")

# %%
hello("Ross")
# Out:
# Hello, Ross!

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /work/IdaBækkeJohannesen#6921/Visual Analytics/cds-vis/session2.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://app-5016053-0.cloud.sdu.dk/work/IdaB%C3%A6kkeJohannesen%236921/Visual%20Analytics/cds-vis/session2.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> hello()
#
# TypeError: hello() missing 1 required positional argument: 'name'

# %%
# the string after the = is the default string to insert, instead of encountering an error when not putting an argument
def hello(name="world"):
    print("Hello, " + name + "!")

# %%
hello("Ross")
# Out:
# Hello, Ross!

# %%
hello()
# Out:
# Hello, world!

# %%
# its good python practice to include a description of what the code does.
def hello(name="world"):
    """
    This function takes a name and prints message to screen
    """
    print("Hello, " + name + "!")

# %% [markdown]
# ### Exercises

# %%
def hellopy():
    print("Hello, what is your name?")
    name = input()
    print("Good to meet you, " + name)
    print("The length of your name is " + str(len(name)))
    print("What is your age?")
    age = input()
    print("You will be " + str((int(age) + 1)) + " in a year")

# %%
hellopy()
# Out:
# Hello, what is your name?
# Good to meet you, Ida
# The length of your name is 3
# What is your age?
# You will be 23 in a year

# %%
>>> mass = 47.5
>>> age = 122
>>> mass = mass * 2.0
>>> age = age - 20

# %%
mass
# Out:
# 95.0

# %%
age
# Out:
# 102

# %% [markdown]
# # Working with image data

# %%
import os
import sys
sys.path.append("..")

# opencv
import cv2
#loading some utility functions
from utils.imutils import jimshow as show

# %%
filepath = os.path.join("..", "..", "..", "cds-vis-data", "data", "img", "trex.png")

# %%
#load using cv2
image = cv2.imread(filepath)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (228, 350, 3)

# %%
show(image)

# %%
# save output
outpath = os.path.join("output", "new_trex.png")
# save image to path
cv2.imwrite(outpath, image)
# Out:
# True

# %% [markdown]
# ### Inspecting images

# %%
# height, width, colour channels
image.shape
# Out:
# (228, 350, 3)

# %%
height = (image.shape[0])
width = (image.shape[1])

# %%
height
# Out:
# 228

# %%
width
# Out:
# 350

# %%
height * width
# Out:
# 79800

# %%
# get pixel values of the first pixel in the top left corner
# listed as BGR, not RGB, for cv
blue, green, red = image[0,0]

# %%
blue
# Out:
# 254

# %%
green
# Out:
# 254

# %%
red
# Out:
# 254

# %%
colours = image[0,0]

# %%
colours
# Out:
# array([254, 254, 254], dtype=uint8)

# %%
# this replaces a pixel with the set colour, cannot be reversed without reloading the image again
image[0,0] = (0,0,255)

# %%
show(image)

# %%
# show first 100x100 pixels
corner =image[0:100,0:100]

# %%
show(corner)

# %%
image[0:100,0:50] = (250,145,250)

# %%
show(image)

# %% [markdown]
# # Extracting histograms

# %%
# for plotting single colour channels
from utils.imutils import jimshow_channel as show_channel

# %%
filepath = os.path.join("..", "..", "..", "cds-vis-data", "data", "img", "t-rex2.png")

# %%
#load using cv2
image = cv2.imread(filepath)

# %%
show(image)

# %%
# splitting into separate channels
B, G, R = cv2.split(image)

# %%
show_channel(G)

# %%
# combine colour channels to create grayscale
grayed_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
show_channel(grayed_image)

# %%
image.flatten().shape
# Out:
# (831096,)

# %%
# import matplotlib
import matplotlib.pyplot as plt

# %%
# create my canvas
plt.figure()
# add my histogram
plt.hist(image.flatten(), 255, [0,256])
# add title
plt.title("grayscale histogram")
plt.xlabel("pixel value")
plt.ylabel("# of pixels")
# show
plt.show()
