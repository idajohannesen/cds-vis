# %% [markdown]
# ## Session 10 - Image search with VGG16 and K-Nearest Neighbours

# %%
# base tools
import os, sys
sys.path.append(os.path.join(".."))

# data analysis
import numpy as np
from numpy.linalg import norm
from tqdm import notebook

# tensorflow
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import (load_img, 
                                                  img_to_array)
from tensorflow.keras.applications.vgg16 import (VGG16, 
                                                 preprocess_input)
# from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# 2024-04-19 14:08:34.313263: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-19 14:08:34.317537: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-19 14:08:34.372834: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-19 14:08:35.215371: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Helper functions

# %% [markdown]
# Q: What kind of preprocessing am I doing here? Why do you think I'm doing it?

# %%
def extract_features(img_path, model):
    """
    Extract features from image data using pretrained model (e.g. VGG16)
    """
    # Define input image shape - remember we need to reshape
    input_shape = (224, 224, 3)
    # load image from file path
    img = load_img(img_path, target_size=(input_shape[0], 
                                          input_shape[1]))
    # convert to array
    img_array = img_to_array(img)
    # expand to fit dimensions
    expanded_img_array = np.expand_dims(img_array, axis=0)
    # preprocess image - see last week's notebook
    preprocessed_img = preprocess_input(expanded_img_array)
    # use the predict function to create feature representation
    features = model.predict(preprocessed_img, verbose=False)
    # flatten
    flattened_features = features.flatten()
    # normalise features
    normalized_features = flattened_features / norm(features)
    return flattened_features

# %% [markdown]
# # Image search

# %% [markdown]
# ## Load VGG16

# %%
model = VGG16(weights='imagenet', 
              include_top=False,
              pooling='avg',
              input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# ## Extract features from single image

# %%
target_image = os.path.join("..", "..", "..", "..", "cds-vis-data", "data", "img", "florence.jpg")
features = extract_features(target_image, model)

# %%
features
# Out:
# array([1.40007484e+00, 0.00000000e+00, 1.89000845e-01, 6.62067235e-01,
#        1.51665936e+01, 0.00000000e+00, 0.00000000e+00, 1.04001081e+00,
#        0.00000000e+00, 0.00000000e+00, 1.10624579e-03, 0.00000000e+00,
#        1.22243173e-01, 0.00000000e+00, 2.58846831e+00, 0.00000000e+00,
#        0.00000000e+00, 1.95303965e+00, 7.72281885e-01, 0.00000000e+00,
#        0.00000000e+00, 1.33256167e-01, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 4.81745863e+00, 0.00000000e+00, 0.00000000e+00,
#        1.47842312e+00, 6.88361451e-02, 5.28677940e+00, 0.00000000e+00,
#        2.45790705e-02, 0.00000000e+00, 4.35872823e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.84966362e+00, 1.91122484e+00, 0.00000000e+00,
#        7.02198029e+00, 2.09627819e+01, 5.37744379e+00, 0.00000000e+00,
#        2.01789856e+00, 1.21550703e+00, 3.72341228e+00, 1.52538881e-01,
#        6.86924398e-01, 5.20135164e+00, 5.31802654e-01, 5.60718203e+00,
#        0.00000000e+00, 1.67730677e+00, 3.48672915e+00, 0.00000000e+00,
#        0.00000000e+00, 1.07589424e+00, 0.00000000e+00, 7.88364410e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.35800609e-01, 0.00000000e+00, 0.00000000e+00, 1.11254595e-01,
#        0.00000000e+00, 8.30990219e+00, 0.00000000e+00, 1.00039506e+00,
#        1.13206112e+00, 1.20783281e+00, 2.31463027e+00, 1.17889166e+01,
#        0.00000000e+00, 1.46104324e+00, 5.99056959e-01, 0.00000000e+00,
#        0.00000000e+00, 4.50259894e-01, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.77947211e+00, 1.42255294e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5.41835204e-02, 8.65926838e+00,
#        8.08400810e-02, 0.00000000e+00, 2.18231368e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 7.18275738e+00, 8.26753199e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.41800857e+00,
#        0.00000000e+00, 1.72789507e-02, 9.14930999e-01, 0.00000000e+00,
#        0.00000000e+00, 1.92771792e+00, 2.65103430e-02, 3.95681787e+00,
#        0.00000000e+00, 1.18578780e+00, 1.63520317e+01, 2.15941548e+00,
#        6.05599785e+00, 1.86839890e+00, 0.00000000e+00, 0.00000000e+00,
#        1.81369610e+01, 2.28583962e-01, 0.00000000e+00, 2.01768875e-01,
#        7.47977614e-01, 7.78031647e-01, 3.96528864e+00, 3.09309304e-01,
#        2.67616844e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 8.83954689e-02, 1.59333456e+00, 7.54167080e-01,
#        1.76526368e-01, 0.00000000e+00, 6.46784961e-01, 1.19847083e+00,
#        7.97636867e-01, 0.00000000e+00, 0.00000000e+00, 3.40085983e+00,
#        6.86954689e+00, 5.42444289e-01, 0.00000000e+00, 2.96005428e-01,
#        7.03252852e-01, 0.00000000e+00, 0.00000000e+00, 1.86870122e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.11721826e+00,
#        0.00000000e+00, 2.74564719e+00, 0.00000000e+00, 0.00000000e+00,
#        3.84508595e-02, 3.10542166e-01, 0.00000000e+00, 0.00000000e+00,
#        3.20135117e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.17165909e+01, 6.82105970e+00, 0.00000000e+00,
#        5.17529678e+00, 8.70022297e-01, 2.38161373e+00, 0.00000000e+00,
#        6.50268257e-01, 2.54856497e-02, 8.02318528e-02, 5.92372119e-01,
#        1.29342442e+01, 0.00000000e+00, 2.71016237e-04, 2.12370679e-01,
#        7.86851454e+00, 0.00000000e+00, 4.15771866e+00, 2.50072777e-01,
#        1.10482693e+00, 0.00000000e+00, 1.68191278e+00, 0.00000000e+00,
#        0.00000000e+00, 3.99377704e-01, 0.00000000e+00, 1.08170539e-01,
#        0.00000000e+00, 0.00000000e+00, 4.82548147e-01, 4.76795495e-01,
#        8.27681160e+00, 7.97586143e-01, 0.00000000e+00, 1.06636234e-01,
#        0.00000000e+00, 2.85870981e+00, 0.00000000e+00, 2.32947826e+00,
#        1.76250100e+00, 0.00000000e+00, 1.54386199e+00, 4.48075593e-01,
#        1.14111459e+00, 0.00000000e+00, 0.00000000e+00, 2.32331848e+01,
#        1.17101793e+01, 0.00000000e+00, 2.02230811e-01, 1.00938404e+00,
#        0.00000000e+00, 1.04181504e+00, 5.21617476e-03, 6.87942505e+00,
#        5.15531361e-01, 6.24297082e-01, 4.95363742e-01, 1.21274861e-02,
#        1.26270056e+00, 0.00000000e+00, 5.97813129e-01, 1.83082178e-01,
#        0.00000000e+00, 2.24357166e+01, 0.00000000e+00, 2.64649391e+00,
#        3.88037038e+00, 0.00000000e+00, 2.50677919e+00, 0.00000000e+00,
#        2.37367619e-02, 8.65960598e-01, 1.18043256e+00, 1.28025854e+00,
#        6.09057570e+00, 0.00000000e+00, 1.20047646e+01, 2.19536662e+00,
#        9.12256956e-01, 8.06241870e-01, 1.27488628e-01, 0.00000000e+00,
#        0.00000000e+00, 2.72364712e+00, 1.43317819e-01, 2.54863238e+00,
#        0.00000000e+00, 0.00000000e+00, 3.86152940e-04, 0.00000000e+00,
#        6.18522286e-01, 0.00000000e+00, 5.75382328e+00, 1.19463339e+01,
#        0.00000000e+00, 3.28249598e+00, 0.00000000e+00, 2.08937550e+00,
#        0.00000000e+00, 2.46606469e-01, 0.00000000e+00, 0.00000000e+00,
#        2.72345483e-01, 2.14731979e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.00667524e+00, 2.69588798e-01, 5.49668252e-01,
#        6.38548660e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.01245441e+01, 8.14332128e-01, 1.58852518e-01, 4.41681719e+00,
#        1.82782078e+00, 0.00000000e+00, 2.04639554e-01, 0.00000000e+00,
#        1.13955975e+00, 0.00000000e+00, 8.39387719e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.19277656e-01,
#        0.00000000e+00, 0.00000000e+00, 5.18168402e+00, 7.83023643e+00,
#        0.00000000e+00, 0.00000000e+00, 1.65790863e+01, 0.00000000e+00,
#        4.36860991e+00, 0.00000000e+00, 2.15933013e+00, 3.05166817e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.65288568e-01,
#        0.00000000e+00, 6.85326040e-01, 2.24184975e-01, 6.24566674e-02,
#        0.00000000e+00, 0.00000000e+00, 7.97985792e-01, 1.00061321e+01,
#        1.90473795e+00, 0.00000000e+00, 5.78938389e+00, 1.38066664e-01,
#        0.00000000e+00, 0.00000000e+00, 1.72869034e+01, 0.00000000e+00,
#        0.00000000e+00, 6.08544871e-02, 6.84845972e+00, 2.75677061e+00,
#        0.00000000e+00, 2.63262348e+01, 3.99705380e-01, 1.01906145e+00,
#        2.80829763e+00, 0.00000000e+00, 0.00000000e+00, 1.40303659e+00,
#        0.00000000e+00, 0.00000000e+00, 3.01149964e-01, 2.49491796e-01,
#        6.53114271e+00, 4.16459054e-01, 4.71634388e-01, 2.04939067e-01,
#        0.00000000e+00, 0.00000000e+00, 2.86021090e+00, 1.27388334e+01,
#        2.83224106e+01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.49445218e-01, 5.43165088e-01,
#        1.10072958e+00, 0.00000000e+00, 0.00000000e+00, 1.58804074e-01,
#        0.00000000e+00, 1.41856802e+00, 0.00000000e+00, 3.70933127e+00,
#        1.82068100e+01, 0.00000000e+00, 5.88923311e+00, 1.31879523e-01,
#        7.56385803e-01, 0.00000000e+00, 5.26818573e-01, 0.00000000e+00,
#        3.78539026e-01, 9.44178998e-01, 3.78086519e+00, 9.60088447e-02,
#        1.75559788e+01, 0.00000000e+00, 2.85180473e+00, 8.47574919e-02,
#        1.38575351e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.58518696e-01, 0.00000000e+00, 7.77044356e-01, 1.02071738e+00,
#        0.00000000e+00, 9.23492610e-01, 0.00000000e+00, 0.00000000e+00,
#        4.96510923e-01, 2.92726636e-01, 3.10570478e+00, 2.88857317e+00,
#        1.66900516e+00, 0.00000000e+00, 6.68255472e+00, 2.01235086e-01,
#        1.90205121e+00, 6.12072754e+00, 2.98478198e+00, 0.00000000e+00,
#        1.48149910e+01, 1.91207513e-01, 0.00000000e+00, 2.89910412e+00,
#        8.53685284e+00, 0.00000000e+00, 9.51516247e+00, 0.00000000e+00,
#        1.54106647e-01, 0.00000000e+00, 1.26013637e-01, 2.14799500e+00,
#        0.00000000e+00, 2.17166185e-01, 1.82904358e+01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.53519964e+00,
#        5.10855556e-01, 0.00000000e+00, 0.00000000e+00, 1.10979815e+01,
#        3.08135837e-01, 2.94094944e+00, 7.96833658e+00, 3.13484406e+00,
#        0.00000000e+00, 2.63411312e+01, 1.01849937e+00, 0.00000000e+00,
#        0.00000000e+00, 1.25230920e+00, 0.00000000e+00, 6.66710472e+00,
#        0.00000000e+00, 1.09531565e+01, 6.65164411e-01, 4.21833880e-02,
#        0.00000000e+00, 2.01987267e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 7.67733335e-01, 0.00000000e+00, 8.56436670e-01,
#        0.00000000e+00, 5.76465547e-01, 3.22957397e-01, 3.30060005e+00,
#        5.27653170e+00, 5.55629671e-01, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.46093285e+00,
#        0.00000000e+00, 2.34128702e-02, 3.01887542e-01, 0.00000000e+00,
#        0.00000000e+00, 6.94620192e-01, 5.67595720e-01, 3.92379254e-01,
#        0.00000000e+00, 0.00000000e+00, 4.29750519e+01, 3.01437378e+00,
#        0.00000000e+00, 7.23049974e+00, 0.00000000e+00, 3.57511789e-01,
#        0.00000000e+00, 2.25646515e+01, 0.00000000e+00, 2.16388047e-01,
#        7.58095837e+00, 3.75473410e-01, 2.56613827e+00, 0.00000000e+00,
#        2.49785376e+00, 0.00000000e+00, 2.72947490e-01, 0.00000000e+00,
#        4.20741224e+00, 0.00000000e+00, 1.52463114e+00, 9.09076095e-01,
#        0.00000000e+00, 0.00000000e+00, 1.51152194e+00, 1.52580605e+01],
#       dtype=float32)

# %% [markdown]
# ## Iterate over folder

# %%
# path to the datasets
root_dir = os.path.join("..", "..", "..", "..", "cds-vis-data", "flowers")
filenames = [root_dir + "/" + name for name in sorted(os.listdir(root_dir))]

# %% [markdown]
# __Extract features for each image__

# %%
filenames
# Out:
# ['../../../../cds-vis-data/flowers/image_0001.jpg',
#  '../../../../cds-vis-data/flowers/image_0002.jpg',
#  '../../../../cds-vis-data/flowers/image_0003.jpg',
#  '../../../../cds-vis-data/flowers/image_0004.jpg',
#  '../../../../cds-vis-data/flowers/image_0005.jpg',
#  '../../../../cds-vis-data/flowers/image_0006.jpg',
#  '../../../../cds-vis-data/flowers/image_0007.jpg',
#  '../../../../cds-vis-data/flowers/image_0008.jpg',
#  '../../../../cds-vis-data/flowers/image_0009.jpg',
#  '../../../../cds-vis-data/flowers/image_0010.jpg',
#  '../../../../cds-vis-data/flowers/image_0011.jpg',
#  '../../../../cds-vis-data/flowers/image_0012.jpg',
#  '../../../../cds-vis-data/flowers/image_0013.jpg',
#  '../../../../cds-vis-data/flowers/image_0014.jpg',
#  '../../../../cds-vis-data/flowers/image_0015.jpg',
#  '../../../../cds-vis-data/flowers/image_0016.jpg',
#  '../../../../cds-vis-data/flowers/image_0017.jpg',
#  '../../../../cds-vis-data/flowers/image_0018.jpg',
#  '../../../../cds-vis-data/flowers/image_0019.jpg',
#  '../../../../cds-vis-data/flowers/image_0020.jpg',
#  '../../../../cds-vis-data/flowers/image_0021.jpg',
#  '../../../../cds-vis-data/flowers/image_0022.jpg',
#  '../../../../cds-vis-data/flowers/image_0023.jpg',
#  '../../../../cds-vis-data/flowers/image_0024.jpg',
#  '../../../../cds-vis-data/flowers/image_0025.jpg',
#  '../../../../cds-vis-data/flowers/image_0026.jpg',
#  '../../../../cds-vis-data/flowers/image_0027.jpg',
#  '../../../../cds-vis-data/flowers/image_0028.jpg',
#  '../../../../cds-vis-data/flowers/image_0029.jpg',
#  '../../../../cds-vis-data/flowers/image_0030.jpg',
#  '../../../../cds-vis-data/flowers/image_0031.jpg',
#  '../../../../cds-vis-data/flowers/image_0032.jpg',
#  '../../../../cds-vis-data/flowers/image_0033.jpg',
#  '../../../../cds-vis-data/flowers/image_0034.jpg',
#  '../../../../cds-vis-data/flowers/image_0035.jpg',
#  '../../../../cds-vis-data/flowers/image_0036.jpg',
#  '../../../../cds-vis-data/flowers/image_0037.jpg',
#  '../../../../cds-vis-data/flowers/image_0038.jpg',
#  '../../../../cds-vis-data/flowers/image_0039.jpg',
#  '../../../../cds-vis-data/flowers/image_0040.jpg',
#  '../../../../cds-vis-data/flowers/image_0041.jpg',
#  '../../../../cds-vis-data/flowers/image_0042.jpg',
#  '../../../../cds-vis-data/flowers/image_0043.jpg',
#  '../../../../cds-vis-data/flowers/image_0044.jpg',
#  '../../../../cds-vis-data/flowers/image_0045.jpg',
#  '../../../../cds-vis-data/flowers/image_0046.jpg',
#  '../../../../cds-vis-data/flowers/image_0047.jpg',
#  '../../../../cds-vis-data/flowers/image_0048.jpg',
#  '../../../../cds-vis-data/flowers/image_0049.jpg',
#  '../../../../cds-vis-data/flowers/image_0050.jpg',
#  '../../../../cds-vis-data/flowers/image_0051.jpg',
#  '../../../../cds-vis-data/flowers/image_0052.jpg',
#  '../../../../cds-vis-data/flowers/image_0053.jpg',
#  '../../../../cds-vis-data/flowers/image_0054.jpg',
#  '../../../../cds-vis-data/flowers/image_0055.jpg',
#  '../../../../cds-vis-data/flowers/image_0056.jpg',
#  '../../../../cds-vis-data/flowers/image_0057.jpg',
#  '../../../../cds-vis-data/flowers/image_0058.jpg',
#  '../../../../cds-vis-data/flowers/image_0059.jpg',
#  '../../../../cds-vis-data/flowers/image_0060.jpg',
#  '../../../../cds-vis-data/flowers/image_0061.jpg',
#  '../../../../cds-vis-data/flowers/image_0062.jpg',
#  '../../../../cds-vis-data/flowers/image_0063.jpg',
#  '../../../../cds-vis-data/flowers/image_0064.jpg',
#  '../../../../cds-vis-data/flowers/image_0065.jpg',
#  '../../../../cds-vis-data/flowers/image_0066.jpg',
#  '../../../../cds-vis-data/flowers/image_0067.jpg',
#  '../../../../cds-vis-data/flowers/image_0068.jpg',
#  '../../../../cds-vis-data/flowers/image_0069.jpg',
#  '../../../../cds-vis-data/flowers/image_0070.jpg',
#  '../../../../cds-vis-data/flowers/image_0071.jpg',
#  '../../../../cds-vis-data/flowers/image_0072.jpg',
#  '../../../../cds-vis-data/flowers/image_0073.jpg',
#  '../../../../cds-vis-data/flowers/image_0074.jpg',
#  '../../../../cds-vis-data/flowers/image_0075.jpg',
#  '../../../../cds-vis-data/flowers/image_0076.jpg',
#  '../../../../cds-vis-data/flowers/image_0077.jpg',
#  '../../../../cds-vis-data/flowers/image_0078.jpg',
#  '../../../../cds-vis-data/flowers/image_0079.jpg',
#  '../../../../cds-vis-data/flowers/image_0080.jpg',
#  '../../../../cds-vis-data/flowers/image_0081.jpg',
#  '../../../../cds-vis-data/flowers/image_0082.jpg',
#  '../../../../cds-vis-data/flowers/image_0083.jpg',
#  '../../../../cds-vis-data/flowers/image_0084.jpg',
#  '../../../../cds-vis-data/flowers/image_0085.jpg',
#  '../../../../cds-vis-data/flowers/image_0086.jpg',
#  '../../../../cds-vis-data/flowers/image_0087.jpg',
#  '../../../../cds-vis-data/flowers/image_0088.jpg',
#  '../../../../cds-vis-data/flowers/image_0089.jpg',
#  '../../../../cds-vis-data/flowers/image_0090.jpg',
#  '../../../../cds-vis-data/flowers/image_0091.jpg',
#  '../../../../cds-vis-data/flowers/image_0092.jpg',
#  '../../../../cds-vis-data/flowers/image_0093.jpg',
#  '../../../../cds-vis-data/flowers/image_0094.jpg',
#  '../../../../cds-vis-data/flowers/image_0095.jpg',
#  '../../../../cds-vis-data/flowers/image_0096.jpg',
#  '../../../../cds-vis-data/flowers/image_0097.jpg',
#  '../../../../cds-vis-data/flowers/image_0098.jpg',
#  '../../../../cds-vis-data/flowers/image_0099.jpg',
#  '../../../../cds-vis-data/flowers/image_0100.jpg',
#  '../../../../cds-vis-data/flowers/image_0101.jpg',
#  '../../../../cds-vis-data/flowers/image_0102.jpg',
#  '../../../../cds-vis-data/flowers/image_0103.jpg',
#  '../../../../cds-vis-data/flowers/image_0104.jpg',
#  '../../../../cds-vis-data/flowers/image_0105.jpg',
#  '../../../../cds-vis-data/flowers/image_0106.jpg',
#  '../../../../cds-vis-data/flowers/image_0107.jpg',
#  '../../../../cds-vis-data/flowers/image_0108.jpg',
#  '../../../../cds-vis-data/flowers/image_0109.jpg',
#  '../../../../cds-vis-data/flowers/image_0110.jpg',
#  '../../../../cds-vis-data/flowers/image_0111.jpg',
#  '../../../../cds-vis-data/flowers/image_0112.jpg',
#  '../../../../cds-vis-data/flowers/image_0113.jpg',
#  '../../../../cds-vis-data/flowers/image_0114.jpg',
#  '../../../../cds-vis-data/flowers/image_0115.jpg',
#  '../../../../cds-vis-data/flowers/image_0116.jpg',
#  '../../../../cds-vis-data/flowers/image_0117.jpg',
#  '../../../../cds-vis-data/flowers/image_0118.jpg',
#  '../../../../cds-vis-data/flowers/image_0119.jpg',
#  '../../../../cds-vis-data/flowers/image_0120.jpg',
#  '../../../../cds-vis-data/flowers/image_0121.jpg',
#  '../../../../cds-vis-data/flowers/image_0122.jpg',
#  '../../../../cds-vis-data/flowers/image_0123.jpg',
#  '../../../../cds-vis-data/flowers/image_0124.jpg',
#  '../../../../cds-vis-data/flowers/image_0125.jpg',
#  '../../../../cds-vis-data/flowers/image_0126.jpg',
#  '../../../../cds-vis-data/flowers/image_0127.jpg',
#  '../../../../cds-vis-data/flowers/image_0128.jpg',
#  '../../../../cds-vis-data/flowers/image_0129.jpg',
#  '../../../../cds-vis-data/flowers/image_0130.jpg',
#  '../../../../cds-vis-data/flowers/image_0131.jpg',
#  '../../../../cds-vis-data/flowers/image_0132.jpg',
#  '../../../../cds-vis-data/flowers/image_0133.jpg',
#  '../../../../cds-vis-data/flowers/image_0134.jpg',
#  '../../../../cds-vis-data/flowers/image_0135.jpg',
#  '../../../../cds-vis-data/flowers/image_0136.jpg',
#  '../../../../cds-vis-data/flowers/image_0137.jpg',
#  '../../../../cds-vis-data/flowers/image_0138.jpg',
#  '../../../../cds-vis-data/flowers/image_0139.jpg',
#  '../../../../cds-vis-data/flowers/image_0140.jpg',
#  '../../../../cds-vis-data/flowers/image_0141.jpg',
#  '../../../../cds-vis-data/flowers/image_0142.jpg',
#  '../../../../cds-vis-data/flowers/image_0143.jpg',
#  '../../../../cds-vis-data/flowers/image_0144.jpg',
#  '../../../../cds-vis-data/flowers/image_0145.jpg',
#  '../../../../cds-vis-data/flowers/image_0146.jpg',
#  '../../../../cds-vis-data/flowers/image_0147.jpg',
#  '../../../../cds-vis-data/flowers/image_0148.jpg',
#  '../../../../cds-vis-data/flowers/image_0149.jpg',
#  '../../../../cds-vis-data/flowers/image_0150.jpg',
#  '../../../../cds-vis-data/flowers/image_0151.jpg',
#  '../../../../cds-vis-data/flowers/image_0152.jpg',
#  '../../../../cds-vis-data/flowers/image_0153.jpg',
#  '../../../../cds-vis-data/flowers/image_0154.jpg',
#  '../../../../cds-vis-data/flowers/image_0155.jpg',
#  '../../../../cds-vis-data/flowers/image_0156.jpg',
#  '../../../../cds-vis-data/flowers/image_0157.jpg',
#  '../../../../cds-vis-data/flowers/image_0158.jpg',
#  '../../../../cds-vis-data/flowers/image_0159.jpg',
#  '../../../../cds-vis-data/flowers/image_0160.jpg',
#  '../../../../cds-vis-data/flowers/image_0161.jpg',
#  '../../../../cds-vis-data/flowers/image_0162.jpg',
#  '../../../../cds-vis-data/flowers/image_0163.jpg',
#  '../../../../cds-vis-data/flowers/image_0164.jpg',
#  '../../../../cds-vis-data/flowers/image_0165.jpg',
#  '../../../../cds-vis-data/flowers/image_0166.jpg',
#  '../../../../cds-vis-data/flowers/image_0167.jpg',
#  '../../../../cds-vis-data/flowers/image_0168.jpg',
#  '../../../../cds-vis-data/flowers/image_0169.jpg',
#  '../../../../cds-vis-data/flowers/image_0170.jpg',
#  '../../../../cds-vis-data/flowers/image_0171.jpg',
#  '../../../../cds-vis-data/flowers/image_0172.jpg',
#  '../../../../cds-vis-data/flowers/image_0173.jpg',
#  '../../../../cds-vis-data/flowers/image_0174.jpg',
#  '../../../../cds-vis-data/flowers/image_0175.jpg',
#  '../../../../cds-vis-data/flowers/image_0176.jpg',
#  '../../../../cds-vis-data/flowers/image_0177.jpg',
#  '../../../../cds-vis-data/flowers/image_0178.jpg',
#  '../../../../cds-vis-data/flowers/image_0179.jpg',
#  '../../../../cds-vis-data/flowers/image_0180.jpg',
#  '../../../../cds-vis-data/flowers/image_0181.jpg',
#  '../../../../cds-vis-data/flowers/image_0182.jpg',
#  '../../../../cds-vis-data/flowers/image_0183.jpg',
#  '../../../../cds-vis-data/flowers/image_0184.jpg',
#  '../../../../cds-vis-data/flowers/image_0185.jpg',
#  '../../../../cds-vis-data/flowers/image_0186.jpg',
#  '../../../../cds-vis-data/flowers/image_0187.jpg',
#  '../../../../cds-vis-data/flowers/image_0188.jpg',
#  '../../../../cds-vis-data/flowers/image_0189.jpg',
#  '../../../../cds-vis-data/flowers/image_0190.jpg',
#  '../../../../cds-vis-data/flowers/image_0191.jpg',
#  '../../../../cds-vis-data/flowers/image_0192.jpg',
#  '../../../../cds-vis-data/flowers/image_0193.jpg',
#  '../../../../cds-vis-data/flowers/image_0194.jpg',
#  '../../../../cds-vis-data/flowers/image_0195.jpg',
#  '../../../../cds-vis-data/flowers/image_0196.jpg',
#  '../../../../cds-vis-data/flowers/image_0197.jpg',
#  '../../../../cds-vis-data/flowers/image_0198.jpg',
#  '../../../../cds-vis-data/flowers/image_0199.jpg',
#  '../../../../cds-vis-data/flowers/image_0200.jpg',
#  '../../../../cds-vis-data/flowers/image_0201.jpg',
#  '../../../../cds-vis-data/flowers/image_0202.jpg',
#  '../../../../cds-vis-data/flowers/image_0203.jpg',
#  '../../../../cds-vis-data/flowers/image_0204.jpg',
#  '../../../../cds-vis-data/flowers/image_0205.jpg',
#  '../../../../cds-vis-data/flowers/image_0206.jpg',
#  '../../../../cds-vis-data/flowers/image_0207.jpg',
#  '../../../../cds-vis-data/flowers/image_0208.jpg',
#  '../../../../cds-vis-data/flowers/image_0209.jpg',
#  '../../../../cds-vis-data/flowers/image_0210.jpg',
#  '../../../../cds-vis-data/flowers/image_0211.jpg',
#  '../../../../cds-vis-data/flowers/image_0212.jpg',
#  '../../../../cds-vis-data/flowers/image_0213.jpg',
#  '../../../../cds-vis-data/flowers/image_0214.jpg',
#  '../../../../cds-vis-data/flowers/image_0215.jpg',
#  '../../../../cds-vis-data/flowers/image_0216.jpg',
#  '../../../../cds-vis-data/flowers/image_0217.jpg',
#  '../../../../cds-vis-data/flowers/image_0218.jpg',
#  '../../../../cds-vis-data/flowers/image_0219.jpg',
#  '../../../../cds-vis-data/flowers/image_0220.jpg',
#  '../../../../cds-vis-data/flowers/image_0221.jpg',
#  '../../../../cds-vis-data/flowers/image_0222.jpg',
#  '../../../../cds-vis-data/flowers/image_0223.jpg',
#  '../../../../cds-vis-data/flowers/image_0224.jpg',
#  '../../../../cds-vis-data/flowers/image_0225.jpg',
#  '../../../../cds-vis-data/flowers/image_0226.jpg',
#  '../../../../cds-vis-data/flowers/image_0227.jpg',
#  '../../../../cds-vis-data/flowers/image_0228.jpg',
#  '../../../../cds-vis-data/flowers/image_0229.jpg',
#  '../../../../cds-vis-data/flowers/image_0230.jpg',
#  '../../../../cds-vis-data/flowers/image_0231.jpg',
#  '../../../../cds-vis-data/flowers/image_0232.jpg',
#  '../../../../cds-vis-data/flowers/image_0233.jpg',
#  '../../../../cds-vis-data/flowers/image_0234.jpg',
#  '../../../../cds-vis-data/flowers/image_0235.jpg',
#  '../../../../cds-vis-data/flowers/image_0236.jpg',
#  '../../../../cds-vis-data/flowers/image_0237.jpg',
#  '../../../../cds-vis-data/flowers/image_0238.jpg',
#  '../../../../cds-vis-data/flowers/image_0239.jpg',
#  '../../../../cds-vis-data/flowers/image_0240.jpg',
#  '../../../../cds-vis-data/flowers/image_0241.jpg',
#  '../../../../cds-vis-data/flowers/image_0242.jpg',
#  '../../../../cds-vis-data/flowers/image_0243.jpg',
#  '../../../../cds-vis-data/flowers/image_0244.jpg',
#  '../../../../cds-vis-data/flowers/image_0245.jpg',
#  '../../../../cds-vis-data/flowers/image_0246.jpg',
#  '../../../../cds-vis-data/flowers/image_0247.jpg',
#  '../../../../cds-vis-data/flowers/image_0248.jpg',
#  '../../../../cds-vis-data/flowers/image_0249.jpg',
#  '../../../../cds-vis-data/flowers/image_0250.jpg',
#  '../../../../cds-vis-data/flowers/image_0251.jpg',
#  '../../../../cds-vis-data/flowers/image_0252.jpg',
#  '../../../../cds-vis-data/flowers/image_0253.jpg',
#  '../../../../cds-vis-data/flowers/image_0254.jpg',
#  '../../../../cds-vis-data/flowers/image_0255.jpg',
#  '../../../../cds-vis-data/flowers/image_0256.jpg',
#  '../../../../cds-vis-data/flowers/image_0257.jpg',
#  '../../../../cds-vis-data/flowers/image_0258.jpg',
#  '../../../../cds-vis-data/flowers/image_0259.jpg',
#  '../../../../cds-vis-data/flowers/image_0260.jpg',
#  '../../../../cds-vis-data/flowers/image_0261.jpg',
#  '../../../../cds-vis-data/flowers/image_0262.jpg',
#  '../../../../cds-vis-data/flowers/image_0263.jpg',
#  '../../../../cds-vis-data/flowers/image_0264.jpg',
#  '../../../../cds-vis-data/flowers/image_0265.jpg',
#  '../../../../cds-vis-data/flowers/image_0266.jpg',
#  '../../../../cds-vis-data/flowers/image_0267.jpg',
#  '../../../../cds-vis-data/flowers/image_0268.jpg',
#  '../../../../cds-vis-data/flowers/image_0269.jpg',
#  '../../../../cds-vis-data/flowers/image_0270.jpg',
#  '../../../../cds-vis-data/flowers/image_0271.jpg',
#  '../../../../cds-vis-data/flowers/image_0272.jpg',
#  '../../../../cds-vis-data/flowers/image_0273.jpg',
#  '../../../../cds-vis-data/flowers/image_0274.jpg',
#  '../../../../cds-vis-data/flowers/image_0275.jpg',
#  '../../../../cds-vis-data/flowers/image_0276.jpg',
#  '../../../../cds-vis-data/flowers/image_0277.jpg',
#  '../../../../cds-vis-data/flowers/image_0278.jpg',
#  '../../../../cds-vis-data/flowers/image_0279.jpg',
#  '../../../../cds-vis-data/flowers/image_0280.jpg',
#  '../../../../cds-vis-data/flowers/image_0281.jpg',
#  '../../../../cds-vis-data/flowers/image_0282.jpg',
#  '../../../../cds-vis-data/flowers/image_0283.jpg',
#  '../../../../cds-vis-data/flowers/image_0284.jpg',
#  '../../../../cds-vis-data/flowers/image_0285.jpg',
#  '../../../../cds-vis-data/flowers/image_0286.jpg',
#  '../../../../cds-vis-data/flowers/image_0287.jpg',
#  '../../../../cds-vis-data/flowers/image_0288.jpg',
#  '../../../../cds-vis-data/flowers/image_0289.jpg',
#  '../../../../cds-vis-data/flowers/image_0290.jpg',
#  '../../../../cds-vis-data/flowers/image_0291.jpg',
#  '../../../../cds-vis-data/flowers/image_0292.jpg',
#  '../../../../cds-vis-data/flowers/image_0293.jpg',
#  '../../../../cds-vis-data/flowers/image_0294.jpg',
#  '../../../../cds-vis-data/flowers/image_0295.jpg',
#  '../../../../cds-vis-data/flowers/image_0296.jpg',
#  '../../../../cds-vis-data/flowers/image_0297.jpg',
#  '../../../../cds-vis-data/flowers/image_0298.jpg',
#  '../../../../cds-vis-data/flowers/image_0299.jpg',
#  '../../../../cds-vis-data/flowers/image_0300.jpg',
#  '../../../../cds-vis-data/flowers/image_0301.jpg',
#  '../../../../cds-vis-data/flowers/image_0302.jpg',
#  '../../../../cds-vis-data/flowers/image_0303.jpg',
#  '../../../../cds-vis-data/flowers/image_0304.jpg',
#  '../../../../cds-vis-data/flowers/image_0305.jpg',
#  '../../../../cds-vis-data/flowers/image_0306.jpg',
#  '../../../../cds-vis-data/flowers/image_0307.jpg',
#  '../../../../cds-vis-data/flowers/image_0308.jpg',
#  '../../../../cds-vis-data/flowers/image_0309.jpg',
#  '../../../../cds-vis-data/flowers/image_0310.jpg',
#  '../../../../cds-vis-data/flowers/image_0311.jpg',
#  '../../../../cds-vis-data/flowers/image_0312.jpg',
#  '../../../../cds-vis-data/flowers/image_0313.jpg',
#  '../../../../cds-vis-data/flowers/image_0314.jpg',
#  '../../../../cds-vis-data/flowers/image_0315.jpg',
#  '../../../../cds-vis-data/flowers/image_0316.jpg',
#  '../../../../cds-vis-data/flowers/image_0317.jpg',
#  '../../../../cds-vis-data/flowers/image_0318.jpg',
#  '../../../../cds-vis-data/flowers/image_0319.jpg',
#  '../../../../cds-vis-data/flowers/image_0320.jpg',
#  '../../../../cds-vis-data/flowers/image_0321.jpg',
#  '../../../../cds-vis-data/flowers/image_0322.jpg',
#  '../../../../cds-vis-data/flowers/image_0323.jpg',
#  '../../../../cds-vis-data/flowers/image_0324.jpg',
#  '../../../../cds-vis-data/flowers/image_0325.jpg',
#  '../../../../cds-vis-data/flowers/image_0326.jpg',
#  '../../../../cds-vis-data/flowers/image_0327.jpg',
#  '../../../../cds-vis-data/flowers/image_0328.jpg',
#  '../../../../cds-vis-data/flowers/image_0329.jpg',
#  '../../../../cds-vis-data/flowers/image_0330.jpg',
#  '../../../../cds-vis-data/flowers/image_0331.jpg',
#  '../../../../cds-vis-data/flowers/image_0332.jpg',
#  '../../../../cds-vis-data/flowers/image_0333.jpg',
#  '../../../../cds-vis-data/flowers/image_0334.jpg',
#  '../../../../cds-vis-data/flowers/image_0335.jpg',
#  '../../../../cds-vis-data/flowers/image_0336.jpg',
#  '../../../../cds-vis-data/flowers/image_0337.jpg',
#  '../../../../cds-vis-data/flowers/image_0338.jpg',
#  '../../../../cds-vis-data/flowers/image_0339.jpg',
#  '../../../../cds-vis-data/flowers/image_0340.jpg',
#  '../../../../cds-vis-data/flowers/image_0341.jpg',
#  '../../../../cds-vis-data/flowers/image_0342.jpg',
#  '../../../../cds-vis-data/flowers/image_0343.jpg',
#  '../../../../cds-vis-data/flowers/image_0344.jpg',
#  '../../../../cds-vis-data/flowers/image_0345.jpg',
#  '../../../../cds-vis-data/flowers/image_0346.jpg',
#  '../../../../cds-vis-data/flowers/image_0347.jpg',
#  '../../../../cds-vis-data/flowers/image_0348.jpg',
#  '../../../../cds-vis-data/flowers/image_0349.jpg',
#  '../../../../cds-vis-data/flowers/image_0350.jpg',
#  '../../../../cds-vis-data/flowers/image_0351.jpg',
#  '../../../../cds-vis-data/flowers/image_0352.jpg',
#  '../../../../cds-vis-data/flowers/image_0353.jpg',
#  '../../../../cds-vis-data/flowers/image_0354.jpg',
#  '../../../../cds-vis-data/flowers/image_0355.jpg',
#  '../../../../cds-vis-data/flowers/image_0356.jpg',
#  '../../../../cds-vis-data/flowers/image_0357.jpg',
#  '../../../../cds-vis-data/flowers/image_0358.jpg',
#  '../../../../cds-vis-data/flowers/image_0359.jpg',
#  '../../../../cds-vis-data/flowers/image_0360.jpg',
#  '../../../../cds-vis-data/flowers/image_0361.jpg',
#  '../../../../cds-vis-data/flowers/image_0362.jpg',
#  '../../../../cds-vis-data/flowers/image_0363.jpg',
#  '../../../../cds-vis-data/flowers/image_0364.jpg',
#  '../../../../cds-vis-data/flowers/image_0365.jpg',
#  '../../../../cds-vis-data/flowers/image_0366.jpg',
#  '../../../../cds-vis-data/flowers/image_0367.jpg',
#  '../../../../cds-vis-data/flowers/image_0368.jpg',
#  '../../../../cds-vis-data/flowers/image_0369.jpg',
#  '../../../../cds-vis-data/flowers/image_0370.jpg',
#  '../../../../cds-vis-data/flowers/image_0371.jpg',
#  '../../../../cds-vis-data/flowers/image_0372.jpg',
#  '../../../../cds-vis-data/flowers/image_0373.jpg',
#  '../../../../cds-vis-data/flowers/image_0374.jpg',
#  '../../../../cds-vis-data/flowers/image_0375.jpg',
#  '../../../../cds-vis-data/flowers/image_0376.jpg',
#  '../../../../cds-vis-data/flowers/image_0377.jpg',
#  '../../../../cds-vis-data/flowers/image_0378.jpg',
#  '../../../../cds-vis-data/flowers/image_0379.jpg',
#  '../../../../cds-vis-data/flowers/image_0380.jpg',
#  '../../../../cds-vis-data/flowers/image_0381.jpg',
#  '../../../../cds-vis-data/flowers/image_0382.jpg',
#  '../../../../cds-vis-data/flowers/image_0383.jpg',
#  '../../../../cds-vis-data/flowers/image_0384.jpg',
#  '../../../../cds-vis-data/flowers/image_0385.jpg',
#  '../../../../cds-vis-data/flowers/image_0386.jpg',
#  '../../../../cds-vis-data/flowers/image_0387.jpg',
#  '../../../../cds-vis-data/flowers/image_0388.jpg',
#  '../../../../cds-vis-data/flowers/image_0389.jpg',
#  '../../../../cds-vis-data/flowers/image_0390.jpg',
#  '../../../../cds-vis-data/flowers/image_0391.jpg',
#  '../../../../cds-vis-data/flowers/image_0392.jpg',
#  '../../../../cds-vis-data/flowers/image_0393.jpg',
#  '../../../../cds-vis-data/flowers/image_0394.jpg',
#  '../../../../cds-vis-data/flowers/image_0395.jpg',
#  '../../../../cds-vis-data/flowers/image_0396.jpg',
#  '../../../../cds-vis-data/flowers/image_0397.jpg',
#  '../../../../cds-vis-data/flowers/image_0398.jpg',
#  '../../../../cds-vis-data/flowers/image_0399.jpg',
#  '../../../../cds-vis-data/flowers/image_0400.jpg',
#  '../../../../cds-vis-data/flowers/image_0401.jpg',
#  '../../../../cds-vis-data/flowers/image_0402.jpg',
#  '../../../../cds-vis-data/flowers/image_0403.jpg',
#  '../../../../cds-vis-data/flowers/image_0404.jpg',
#  '../../../../cds-vis-data/flowers/image_0405.jpg',
#  '../../../../cds-vis-data/flowers/image_0406.jpg',
#  '../../../../cds-vis-data/flowers/image_0407.jpg',
#  '../../../../cds-vis-data/flowers/image_0408.jpg',
#  '../../../../cds-vis-data/flowers/image_0409.jpg',
#  '../../../../cds-vis-data/flowers/image_0410.jpg',
#  '../../../../cds-vis-data/flowers/image_0411.jpg',
#  '../../../../cds-vis-data/flowers/image_0412.jpg',
#  '../../../../cds-vis-data/flowers/image_0413.jpg',
#  '../../../../cds-vis-data/flowers/image_0414.jpg',
#  '../../../../cds-vis-data/flowers/image_0415.jpg',
#  '../../../../cds-vis-data/flowers/image_0416.jpg',
#  '../../../../cds-vis-data/flowers/image_0417.jpg',
#  '../../../../cds-vis-data/flowers/image_0418.jpg',
#  '../../../../cds-vis-data/flowers/image_0419.jpg',
#  '../../../../cds-vis-data/flowers/image_0420.jpg',
#  '../../../../cds-vis-data/flowers/image_0421.jpg',
#  '../../../../cds-vis-data/flowers/image_0422.jpg',
#  '../../../../cds-vis-data/flowers/image_0423.jpg',
#  '../../../../cds-vis-data/flowers/image_0424.jpg',
#  '../../../../cds-vis-data/flowers/image_0425.jpg',
#  '../../../../cds-vis-data/flowers/image_0426.jpg',
#  '../../../../cds-vis-data/flowers/image_0427.jpg',
#  '../../../../cds-vis-data/flowers/image_0428.jpg',
#  '../../../../cds-vis-data/flowers/image_0429.jpg',
#  '../../../../cds-vis-data/flowers/image_0430.jpg',
#  '../../../../cds-vis-data/flowers/image_0431.jpg',
#  '../../../../cds-vis-data/flowers/image_0432.jpg',
#  '../../../../cds-vis-data/flowers/image_0433.jpg',
#  '../../../../cds-vis-data/flowers/image_0434.jpg',
#  '../../../../cds-vis-data/flowers/image_0435.jpg',
#  '../../../../cds-vis-data/flowers/image_0436.jpg',
#  '../../../../cds-vis-data/flowers/image_0437.jpg',
#  '../../../../cds-vis-data/flowers/image_0438.jpg',
#  '../../../../cds-vis-data/flowers/image_0439.jpg',
#  '../../../../cds-vis-data/flowers/image_0440.jpg',
#  '../../../../cds-vis-data/flowers/image_0441.jpg',
#  '../../../../cds-vis-data/flowers/image_0442.jpg',
#  '../../../../cds-vis-data/flowers/image_0443.jpg',
#  '../../../../cds-vis-data/flowers/image_0444.jpg',
#  '../../../../cds-vis-data/flowers/image_0445.jpg',
#  '../../../../cds-vis-data/flowers/image_0446.jpg',
#  '../../../../cds-vis-data/flowers/image_0447.jpg',
#  '../../../../cds-vis-data/flowers/image_0448.jpg',
#  '../../../../cds-vis-data/flowers/image_0449.jpg',
#  '../../../../cds-vis-data/flowers/image_0450.jpg',
#  '../../../../cds-vis-data/flowers/image_0451.jpg',
#  '../../../../cds-vis-data/flowers/image_0452.jpg',
#  '../../../../cds-vis-data/flowers/image_0453.jpg',
#  '../../../../cds-vis-data/flowers/image_0454.jpg',
#  '../../../../cds-vis-data/flowers/image_0455.jpg',
#  '../../../../cds-vis-data/flowers/image_0456.jpg',
#  '../../../../cds-vis-data/flowers/image_0457.jpg',
#  '../../../../cds-vis-data/flowers/image_0458.jpg',
#  '../../../../cds-vis-data/flowers/image_0459.jpg',
#  '../../../../cds-vis-data/flowers/image_0460.jpg',
#  '../../../../cds-vis-data/flowers/image_0461.jpg',
#  '../../../../cds-vis-data/flowers/image_0462.jpg',
#  '../../../../cds-vis-data/flowers/image_0463.jpg',
#  '../../../../cds-vis-data/flowers/image_0464.jpg',
#  '../../../../cds-vis-data/flowers/image_0465.jpg',
#  '../../../../cds-vis-data/flowers/image_0466.jpg',
#  '../../../../cds-vis-data/flowers/image_0467.jpg',
#  '../../../../cds-vis-data/flowers/image_0468.jpg',
#  '../../../../cds-vis-data/flowers/image_0469.jpg',
#  '../../../../cds-vis-data/flowers/image_0470.jpg',
#  '../../../../cds-vis-data/flowers/image_0471.jpg',
#  '../../../../cds-vis-data/flowers/image_0472.jpg',
#  '../../../../cds-vis-data/flowers/image_0473.jpg',
#  '../../../../cds-vis-data/flowers/image_0474.jpg',
#  '../../../../cds-vis-data/flowers/image_0475.jpg',
#  '../../../../cds-vis-data/flowers/image_0476.jpg',
#  '../../../../cds-vis-data/flowers/image_0477.jpg',
#  '../../../../cds-vis-data/flowers/image_0478.jpg',
#  '../../../../cds-vis-data/flowers/image_0479.jpg',
#  '../../../../cds-vis-data/flowers/image_0480.jpg',
#  '../../../../cds-vis-data/flowers/image_0481.jpg',
#  '../../../../cds-vis-data/flowers/image_0482.jpg',
#  '../../../../cds-vis-data/flowers/image_0483.jpg',
#  '../../../../cds-vis-data/flowers/image_0484.jpg',
#  '../../../../cds-vis-data/flowers/image_0485.jpg',
#  '../../../../cds-vis-data/flowers/image_0486.jpg',
#  '../../../../cds-vis-data/flowers/image_0487.jpg',
#  '../../../../cds-vis-data/flowers/image_0488.jpg',
#  '../../../../cds-vis-data/flowers/image_0489.jpg',
#  '../../../../cds-vis-data/flowers/image_0490.jpg',
#  '../../../../cds-vis-data/flowers/image_0491.jpg',
#  '../../../../cds-vis-data/flowers/image_0492.jpg',
#  '../../../../cds-vis-data/flowers/image_0493.jpg',
#  '../../../../cds-vis-data/flowers/image_0494.jpg',
#  '../../../../cds-vis-data/flowers/image_0495.jpg',
#  '../../../../cds-vis-data/flowers/image_0496.jpg',
#  '../../../../cds-vis-data/flowers/image_0497.jpg',
#  '../../../../cds-vis-data/flowers/image_0498.jpg',
#  '../../../../cds-vis-data/flowers/image_0499.jpg',
#  '../../../../cds-vis-data/flowers/image_0500.jpg',
#  '../../../../cds-vis-data/flowers/image_0501.jpg',
#  '../../../../cds-vis-data/flowers/image_0502.jpg',
#  '../../../../cds-vis-data/flowers/image_0503.jpg',
#  '../../../../cds-vis-data/flowers/image_0504.jpg',
#  '../../../../cds-vis-data/flowers/image_0505.jpg',
#  '../../../../cds-vis-data/flowers/image_0506.jpg',
#  '../../../../cds-vis-data/flowers/image_0507.jpg',
#  '../../../../cds-vis-data/flowers/image_0508.jpg',
#  '../../../../cds-vis-data/flowers/image_0509.jpg',
#  '../../../../cds-vis-data/flowers/image_0510.jpg',
#  '../../../../cds-vis-data/flowers/image_0511.jpg',
#  '../../../../cds-vis-data/flowers/image_0512.jpg',
#  '../../../../cds-vis-data/flowers/image_0513.jpg',
#  '../../../../cds-vis-data/flowers/image_0514.jpg',
#  '../../../../cds-vis-data/flowers/image_0515.jpg',
#  '../../../../cds-vis-data/flowers/image_0516.jpg',
#  '../../../../cds-vis-data/flowers/image_0517.jpg',
#  '../../../../cds-vis-data/flowers/image_0518.jpg',
#  '../../../../cds-vis-data/flowers/image_0519.jpg',
#  '../../../../cds-vis-data/flowers/image_0520.jpg',
#  '../../../../cds-vis-data/flowers/image_0521.jpg',
#  '../../../../cds-vis-data/flowers/image_0522.jpg',
#  '../../../../cds-vis-data/flowers/image_0523.jpg',
#  '../../../../cds-vis-data/flowers/image_0524.jpg',
#  '../../../../cds-vis-data/flowers/image_0525.jpg',
#  '../../../../cds-vis-data/flowers/image_0526.jpg',
#  '../../../../cds-vis-data/flowers/image_0527.jpg',
#  '../../../../cds-vis-data/flowers/image_0528.jpg',
#  '../../../../cds-vis-data/flowers/image_0529.jpg',
#  '../../../../cds-vis-data/flowers/image_0530.jpg',
#  '../../../../cds-vis-data/flowers/image_0531.jpg',
#  '../../../../cds-vis-data/flowers/image_0532.jpg',
#  '../../../../cds-vis-data/flowers/image_0533.jpg',
#  '../../../../cds-vis-data/flowers/image_0534.jpg',
#  '../../../../cds-vis-data/flowers/image_0535.jpg',
#  '../../../../cds-vis-data/flowers/image_0536.jpg',
#  '../../../../cds-vis-data/flowers/image_0537.jpg',
#  '../../../../cds-vis-data/flowers/image_0538.jpg',
#  '../../../../cds-vis-data/flowers/image_0539.jpg',
#  '../../../../cds-vis-data/flowers/image_0540.jpg',
#  '../../../../cds-vis-data/flowers/image_0541.jpg',
#  '../../../../cds-vis-data/flowers/image_0542.jpg',
#  '../../../../cds-vis-data/flowers/image_0543.jpg',
#  '../../../../cds-vis-data/flowers/image_0544.jpg',
#  '../../../../cds-vis-data/flowers/image_0545.jpg',
#  '../../../../cds-vis-data/flowers/image_0546.jpg',
#  '../../../../cds-vis-data/flowers/image_0547.jpg',
#  '../../../../cds-vis-data/flowers/image_0548.jpg',
#  '../../../../cds-vis-data/flowers/image_0549.jpg',
#  '../../../../cds-vis-data/flowers/image_0550.jpg',
#  '../../../../cds-vis-data/flowers/image_0551.jpg',
#  '../../../../cds-vis-data/flowers/image_0552.jpg',
#  '../../../../cds-vis-data/flowers/image_0553.jpg',
#  '../../../../cds-vis-data/flowers/image_0554.jpg',
#  '../../../../cds-vis-data/flowers/image_0555.jpg',
#  '../../../../cds-vis-data/flowers/image_0556.jpg',
#  '../../../../cds-vis-data/flowers/image_0557.jpg',
#  '../../../../cds-vis-data/flowers/image_0558.jpg',
#  '../../../../cds-vis-data/flowers/image_0559.jpg',
#  '../../../../cds-vis-data/flowers/image_0560.jpg',
#  '../../../../cds-vis-data/flowers/image_0561.jpg',
#  '../../../../cds-vis-data/flowers/image_0562.jpg',
#  '../../../../cds-vis-data/flowers/image_0563.jpg',
#  '../../../../cds-vis-data/flowers/image_0564.jpg',
#  '../../../../cds-vis-data/flowers/image_0565.jpg',
#  '../../../../cds-vis-data/flowers/image_0566.jpg',
#  '../../../../cds-vis-data/flowers/image_0567.jpg',
#  '../../../../cds-vis-data/flowers/image_0568.jpg',
#  '../../../../cds-vis-data/flowers/image_0569.jpg',
#  '../../../../cds-vis-data/flowers/image_0570.jpg',
#  '../../../../cds-vis-data/flowers/image_0571.jpg',
#  '../../../../cds-vis-data/flowers/image_0572.jpg',
#  '../../../../cds-vis-data/flowers/image_0573.jpg',
#  '../../../../cds-vis-data/flowers/image_0574.jpg',
#  '../../../../cds-vis-data/flowers/image_0575.jpg',
#  '../../../../cds-vis-data/flowers/image_0576.jpg',
#  '../../../../cds-vis-data/flowers/image_0577.jpg',
#  '../../../../cds-vis-data/flowers/image_0578.jpg',
#  '../../../../cds-vis-data/flowers/image_0579.jpg',
#  '../../../../cds-vis-data/flowers/image_0580.jpg',
#  '../../../../cds-vis-data/flowers/image_0581.jpg',
#  '../../../../cds-vis-data/flowers/image_0582.jpg',
#  '../../../../cds-vis-data/flowers/image_0583.jpg',
#  '../../../../cds-vis-data/flowers/image_0584.jpg',
#  '../../../../cds-vis-data/flowers/image_0585.jpg',
#  '../../../../cds-vis-data/flowers/image_0586.jpg',
#  '../../../../cds-vis-data/flowers/image_0587.jpg',
#  '../../../../cds-vis-data/flowers/image_0588.jpg',
#  '../../../../cds-vis-data/flowers/image_0589.jpg',
#  '../../../../cds-vis-data/flowers/image_0590.jpg',
#  '../../../../cds-vis-data/flowers/image_0591.jpg',
#  '../../../../cds-vis-data/flowers/image_0592.jpg',
#  '../../../../cds-vis-data/flowers/image_0593.jpg',
#  '../../../../cds-vis-data/flowers/image_0594.jpg',
#  '../../../../cds-vis-data/flowers/image_0595.jpg',
#  '../../../../cds-vis-data/flowers/image_0596.jpg',
#  '../../../../cds-vis-data/flowers/image_0597.jpg',
#  '../../../../cds-vis-data/flowers/image_0598.jpg',
#  '../../../../cds-vis-data/flowers/image_0599.jpg',
#  '../../../../cds-vis-data/flowers/image_0600.jpg',
#  '../../../../cds-vis-data/flowers/image_0601.jpg',
#  '../../../../cds-vis-data/flowers/image_0602.jpg',
#  '../../../../cds-vis-data/flowers/image_0603.jpg',
#  '../../../../cds-vis-data/flowers/image_0604.jpg',
#  '../../../../cds-vis-data/flowers/image_0605.jpg',
#  '../../../../cds-vis-data/flowers/image_0606.jpg',
#  '../../../../cds-vis-data/flowers/image_0607.jpg',
#  '../../../../cds-vis-data/flowers/image_0608.jpg',
#  '../../../../cds-vis-data/flowers/image_0609.jpg',
#  '../../../../cds-vis-data/flowers/image_0610.jpg',
#  '../../../../cds-vis-data/flowers/image_0611.jpg',
#  '../../../../cds-vis-data/flowers/image_0612.jpg',
#  '../../../../cds-vis-data/flowers/image_0613.jpg',
#  '../../../../cds-vis-data/flowers/image_0614.jpg',
#  '../../../../cds-vis-data/flowers/image_0615.jpg',
#  '../../../../cds-vis-data/flowers/image_0616.jpg',
#  '../../../../cds-vis-data/flowers/image_0617.jpg',
#  '../../../../cds-vis-data/flowers/image_0618.jpg',
#  '../../../../cds-vis-data/flowers/image_0619.jpg',
#  '../../../../cds-vis-data/flowers/image_0620.jpg',
#  '../../../../cds-vis-data/flowers/image_0621.jpg',
#  '../../../../cds-vis-data/flowers/image_0622.jpg',
#  '../../../../cds-vis-data/flowers/image_0623.jpg',
#  '../../../../cds-vis-data/flowers/image_0624.jpg',
#  '../../../../cds-vis-data/flowers/image_0625.jpg',
#  '../../../../cds-vis-data/flowers/image_0626.jpg',
#  '../../../../cds-vis-data/flowers/image_0627.jpg',
#  '../../../../cds-vis-data/flowers/image_0628.jpg',
#  '../../../../cds-vis-data/flowers/image_0629.jpg',
#  '../../../../cds-vis-data/flowers/image_0630.jpg',
#  '../../../../cds-vis-data/flowers/image_0631.jpg',
#  '../../../../cds-vis-data/flowers/image_0632.jpg',
#  '../../../../cds-vis-data/flowers/image_0633.jpg',
#  '../../../../cds-vis-data/flowers/image_0634.jpg',
#  '../../../../cds-vis-data/flowers/image_0635.jpg',
#  '../../../../cds-vis-data/flowers/image_0636.jpg',
#  '../../../../cds-vis-data/flowers/image_0637.jpg',
#  '../../../../cds-vis-data/flowers/image_0638.jpg',
#  '../../../../cds-vis-data/flowers/image_0639.jpg',
#  '../../../../cds-vis-data/flowers/image_0640.jpg',
#  '../../../../cds-vis-data/flowers/image_0641.jpg',
#  '../../../../cds-vis-data/flowers/image_0642.jpg',
#  '../../../../cds-vis-data/flowers/image_0643.jpg',
#  '../../../../cds-vis-data/flowers/image_0644.jpg',
#  '../../../../cds-vis-data/flowers/image_0645.jpg',
#  '../../../../cds-vis-data/flowers/image_0646.jpg',
#  '../../../../cds-vis-data/flowers/image_0647.jpg',
#  '../../../../cds-vis-data/flowers/image_0648.jpg',
#  '../../../../cds-vis-data/flowers/image_0649.jpg',
#  '../../../../cds-vis-data/flowers/image_0650.jpg',
#  '../../../../cds-vis-data/flowers/image_0651.jpg',
#  '../../../../cds-vis-data/flowers/image_0652.jpg',
#  '../../../../cds-vis-data/flowers/image_0653.jpg',
#  '../../../../cds-vis-data/flowers/image_0654.jpg',
#  '../../../../cds-vis-data/flowers/image_0655.jpg',
#  '../../../../cds-vis-data/flowers/image_0656.jpg',
#  '../../../../cds-vis-data/flowers/image_0657.jpg',
#  '../../../../cds-vis-data/flowers/image_0658.jpg',
#  '../../../../cds-vis-data/flowers/image_0659.jpg',
#  '../../../../cds-vis-data/flowers/image_0660.jpg',
#  '../../../../cds-vis-data/flowers/image_0661.jpg',
#  '../../../../cds-vis-data/flowers/image_0662.jpg',
#  '../../../../cds-vis-data/flowers/image_0663.jpg',
#  '../../../../cds-vis-data/flowers/image_0664.jpg',
#  '../../../../cds-vis-data/flowers/image_0665.jpg',
#  '../../../../cds-vis-data/flowers/image_0666.jpg',
#  '../../../../cds-vis-data/flowers/image_0667.jpg',
#  '../../../../cds-vis-data/flowers/image_0668.jpg',
#  '../../../../cds-vis-data/flowers/image_0669.jpg',
#  '../../../../cds-vis-data/flowers/image_0670.jpg',
#  '../../../../cds-vis-data/flowers/image_0671.jpg',
#  '../../../../cds-vis-data/flowers/image_0672.jpg',
#  '../../../../cds-vis-data/flowers/image_0673.jpg',
#  '../../../../cds-vis-data/flowers/image_0674.jpg',
#  '../../../../cds-vis-data/flowers/image_0675.jpg',
#  '../../../../cds-vis-data/flowers/image_0676.jpg',
#  '../../../../cds-vis-data/flowers/image_0677.jpg',
#  '../../../../cds-vis-data/flowers/image_0678.jpg',
#  '../../../../cds-vis-data/flowers/image_0679.jpg',
#  '../../../../cds-vis-data/flowers/image_0680.jpg',
#  '../../../../cds-vis-data/flowers/image_0681.jpg',
#  '../../../../cds-vis-data/flowers/image_0682.jpg',
#  '../../../../cds-vis-data/flowers/image_0683.jpg',
#  '../../../../cds-vis-data/flowers/image_0684.jpg',
#  '../../../../cds-vis-data/flowers/image_0685.jpg',
#  '../../../../cds-vis-data/flowers/image_0686.jpg',
#  '../../../../cds-vis-data/flowers/image_0687.jpg',
#  '../../../../cds-vis-data/flowers/image_0688.jpg',
#  '../../../../cds-vis-data/flowers/image_0689.jpg',
#  '../../../../cds-vis-data/flowers/image_0690.jpg',
#  '../../../../cds-vis-data/flowers/image_0691.jpg',
#  '../../../../cds-vis-data/flowers/image_0692.jpg',
#  '../../../../cds-vis-data/flowers/image_0693.jpg',
#  '../../../../cds-vis-data/flowers/image_0694.jpg',
#  '../../../../cds-vis-data/flowers/image_0695.jpg',
#  '../../../../cds-vis-data/flowers/image_0696.jpg',
#  '../../../../cds-vis-data/flowers/image_0697.jpg',
#  '../../../../cds-vis-data/flowers/image_0698.jpg',
#  '../../../../cds-vis-data/flowers/image_0699.jpg',
#  '../../../../cds-vis-data/flowers/image_0700.jpg',
#  '../../../../cds-vis-data/flowers/image_0701.jpg',
#  '../../../../cds-vis-data/flowers/image_0702.jpg',
#  '../../../../cds-vis-data/flowers/image_0703.jpg',
#  '../../../../cds-vis-data/flowers/image_0704.jpg',
#  '../../../../cds-vis-data/flowers/image_0705.jpg',
#  '../../../../cds-vis-data/flowers/image_0706.jpg',
#  '../../../../cds-vis-data/flowers/image_0707.jpg',
#  '../../../../cds-vis-data/flowers/image_0708.jpg',
#  '../../../../cds-vis-data/flowers/image_0709.jpg',
#  '../../../../cds-vis-data/flowers/image_0710.jpg',
#  '../../../../cds-vis-data/flowers/image_0711.jpg',
#  '../../../../cds-vis-data/flowers/image_0712.jpg',
#  '../../../../cds-vis-data/flowers/image_0713.jpg',
#  '../../../../cds-vis-data/flowers/image_0714.jpg',
#  '../../../../cds-vis-data/flowers/image_0715.jpg',
#  '../../../../cds-vis-data/flowers/image_0716.jpg',
#  '../../../../cds-vis-data/flowers/image_0717.jpg',
#  '../../../../cds-vis-data/flowers/image_0718.jpg',
#  '../../../../cds-vis-data/flowers/image_0719.jpg',
#  '../../../../cds-vis-data/flowers/image_0720.jpg',
#  '../../../../cds-vis-data/flowers/image_0721.jpg',
#  '../../../../cds-vis-data/flowers/image_0722.jpg',
#  '../../../../cds-vis-data/flowers/image_0723.jpg',
#  '../../../../cds-vis-data/flowers/image_0724.jpg',
#  '../../../../cds-vis-data/flowers/image_0725.jpg',
#  '../../../../cds-vis-data/flowers/image_0726.jpg',
#  '../../../../cds-vis-data/flowers/image_0727.jpg',
#  '../../../../cds-vis-data/flowers/image_0728.jpg',
#  '../../../../cds-vis-data/flowers/image_0729.jpg',
#  '../../../../cds-vis-data/flowers/image_0730.jpg',
#  '../../../../cds-vis-data/flowers/image_0731.jpg',
#  '../../../../cds-vis-data/flowers/image_0732.jpg',
#  '../../../../cds-vis-data/flowers/image_0733.jpg',
#  '../../../../cds-vis-data/flowers/image_0734.jpg',
#  '../../../../cds-vis-data/flowers/image_0735.jpg',
#  '../../../../cds-vis-data/flowers/image_0736.jpg',
#  '../../../../cds-vis-data/flowers/image_0737.jpg',
#  '../../../../cds-vis-data/flowers/image_0738.jpg',
#  '../../../../cds-vis-data/flowers/image_0739.jpg',
#  '../../../../cds-vis-data/flowers/image_0740.jpg',
#  '../../../../cds-vis-data/flowers/image_0741.jpg',
#  '../../../../cds-vis-data/flowers/image_0742.jpg',
#  '../../../../cds-vis-data/flowers/image_0743.jpg',
#  '../../../../cds-vis-data/flowers/image_0744.jpg',
#  '../../../../cds-vis-data/flowers/image_0745.jpg',
#  '../../../../cds-vis-data/flowers/image_0746.jpg',
#  '../../../../cds-vis-data/flowers/image_0747.jpg',
#  '../../../../cds-vis-data/flowers/image_0748.jpg',
#  '../../../../cds-vis-data/flowers/image_0749.jpg',
#  '../../../../cds-vis-data/flowers/image_0750.jpg',
#  '../../../../cds-vis-data/flowers/image_0751.jpg',
#  '../../../../cds-vis-data/flowers/image_0752.jpg',
#  '../../../../cds-vis-data/flowers/image_0753.jpg',
#  '../../../../cds-vis-data/flowers/image_0754.jpg',
#  '../../../../cds-vis-data/flowers/image_0755.jpg',
#  '../../../../cds-vis-data/flowers/image_0756.jpg',
#  '../../../../cds-vis-data/flowers/image_0757.jpg',
#  '../../../../cds-vis-data/flowers/image_0758.jpg',
#  '../../../../cds-vis-data/flowers/image_0759.jpg',
#  '../../../../cds-vis-data/flowers/image_0760.jpg',
#  '../../../../cds-vis-data/flowers/image_0761.jpg',
#  '../../../../cds-vis-data/flowers/image_0762.jpg',
#  '../../../../cds-vis-data/flowers/image_0763.jpg',
#  '../../../../cds-vis-data/flowers/image_0764.jpg',
#  '../../../../cds-vis-data/flowers/image_0765.jpg',
#  '../../../../cds-vis-data/flowers/image_0766.jpg',
#  '../../../../cds-vis-data/flowers/image_0767.jpg',
#  '../../../../cds-vis-data/flowers/image_0768.jpg',
#  '../../../../cds-vis-data/flowers/image_0769.jpg',
#  '../../../../cds-vis-data/flowers/image_0770.jpg',
#  '../../../../cds-vis-data/flowers/image_0771.jpg',
#  '../../../../cds-vis-data/flowers/image_0772.jpg',
#  '../../../../cds-vis-data/flowers/image_0773.jpg',
#  '../../../../cds-vis-data/flowers/image_0774.jpg',
#  '../../../../cds-vis-data/flowers/image_0775.jpg',
#  '../../../../cds-vis-data/flowers/image_0776.jpg',
#  '../../../../cds-vis-data/flowers/image_0777.jpg',
#  '../../../../cds-vis-data/flowers/image_0778.jpg',
#  '../../../../cds-vis-data/flowers/image_0779.jpg',
#  '../../../../cds-vis-data/flowers/image_0780.jpg',
#  '../../../../cds-vis-data/flowers/image_0781.jpg',
#  '../../../../cds-vis-data/flowers/image_0782.jpg',
#  '../../../../cds-vis-data/flowers/image_0783.jpg',
#  '../../../../cds-vis-data/flowers/image_0784.jpg',
#  '../../../../cds-vis-data/flowers/image_0785.jpg',
#  '../../../../cds-vis-data/flowers/image_0786.jpg',
#  '../../../../cds-vis-data/flowers/image_0787.jpg',
#  '../../../../cds-vis-data/flowers/image_0788.jpg',
#  '../../../../cds-vis-data/flowers/image_0789.jpg',
#  '../../../../cds-vis-data/flowers/image_0790.jpg',
#  '../../../../cds-vis-data/flowers/image_0791.jpg',
#  '../../../../cds-vis-data/flowers/image_0792.jpg',
#  '../../../../cds-vis-data/flowers/image_0793.jpg',
#  '../../../../cds-vis-data/flowers/image_0794.jpg',
#  '../../../../cds-vis-data/flowers/image_0795.jpg',
#  '../../../../cds-vis-data/flowers/image_0796.jpg',
#  '../../../../cds-vis-data/flowers/image_0797.jpg',
#  '../../../../cds-vis-data/flowers/image_0798.jpg',
#  '../../../../cds-vis-data/flowers/image_0799.jpg',
#  '../../../../cds-vis-data/flowers/image_0800.jpg',
#  '../../../../cds-vis-data/flowers/image_0801.jpg',
#  '../../../../cds-vis-data/flowers/image_0802.jpg',
#  '../../../../cds-vis-data/flowers/image_0803.jpg',
#  '../../../../cds-vis-data/flowers/image_0804.jpg',
#  '../../../../cds-vis-data/flowers/image_0805.jpg',
#  '../../../../cds-vis-data/flowers/image_0806.jpg',
#  '../../../../cds-vis-data/flowers/image_0807.jpg',
#  '../../../../cds-vis-data/flowers/image_0808.jpg',
#  '../../../../cds-vis-data/flowers/image_0809.jpg',
#  '../../../../cds-vis-data/flowers/image_0810.jpg',
#  '../../../../cds-vis-data/flowers/image_0811.jpg',
#  '../../../../cds-vis-data/flowers/image_0812.jpg',
#  '../../../../cds-vis-data/flowers/image_0813.jpg',
#  '../../../../cds-vis-data/flowers/image_0814.jpg',
#  '../../../../cds-vis-data/flowers/image_0815.jpg',
#  '../../../../cds-vis-data/flowers/image_0816.jpg',
#  '../../../../cds-vis-data/flowers/image_0817.jpg',
#  '../../../../cds-vis-data/flowers/image_0818.jpg',
#  '../../../../cds-vis-data/flowers/image_0819.jpg',
#  '../../../../cds-vis-data/flowers/image_0820.jpg',
#  '../../../../cds-vis-data/flowers/image_0821.jpg',
#  '../../../../cds-vis-data/flowers/image_0822.jpg',
#  '../../../../cds-vis-data/flowers/image_0823.jpg',
#  '../../../../cds-vis-data/flowers/image_0824.jpg',
#  '../../../../cds-vis-data/flowers/image_0825.jpg',
#  '../../../../cds-vis-data/flowers/image_0826.jpg',
#  '../../../../cds-vis-data/flowers/image_0827.jpg',
#  '../../../../cds-vis-data/flowers/image_0828.jpg',
#  '../../../../cds-vis-data/flowers/image_0829.jpg',
#  '../../../../cds-vis-data/flowers/image_0830.jpg',
#  '../../../../cds-vis-data/flowers/image_0831.jpg',
#  '../../../../cds-vis-data/flowers/image_0832.jpg',
#  '../../../../cds-vis-data/flowers/image_0833.jpg',
#  '../../../../cds-vis-data/flowers/image_0834.jpg',
#  '../../../../cds-vis-data/flowers/image_0835.jpg',
#  '../../../../cds-vis-data/flowers/image_0836.jpg',
#  '../../../../cds-vis-data/flowers/image_0837.jpg',
#  '../../../../cds-vis-data/flowers/image_0838.jpg',
#  '../../../../cds-vis-data/flowers/image_0839.jpg',
#  '../../../../cds-vis-data/flowers/image_0840.jpg',
#  '../../../../cds-vis-data/flowers/image_0841.jpg',
#  '../../../../cds-vis-data/flowers/image_0842.jpg',
#  '../../../../cds-vis-data/flowers/image_0843.jpg',
#  '../../../../cds-vis-data/flowers/image_0844.jpg',
#  '../../../../cds-vis-data/flowers/image_0845.jpg',
#  '../../../../cds-vis-data/flowers/image_0846.jpg',
#  '../../../../cds-vis-data/flowers/image_0847.jpg',
#  '../../../../cds-vis-data/flowers/image_0848.jpg',
#  '../../../../cds-vis-data/flowers/image_0849.jpg',
#  '../../../../cds-vis-data/flowers/image_0850.jpg',
#  '../../../../cds-vis-data/flowers/image_0851.jpg',
#  '../../../../cds-vis-data/flowers/image_0852.jpg',
#  '../../../../cds-vis-data/flowers/image_0853.jpg',
#  '../../../../cds-vis-data/flowers/image_0854.jpg',
#  '../../../../cds-vis-data/flowers/image_0855.jpg',
#  '../../../../cds-vis-data/flowers/image_0856.jpg',
#  '../../../../cds-vis-data/flowers/image_0857.jpg',
#  '../../../../cds-vis-data/flowers/image_0858.jpg',
#  '../../../../cds-vis-data/flowers/image_0859.jpg',
#  '../../../../cds-vis-data/flowers/image_0860.jpg',
#  '../../../../cds-vis-data/flowers/image_0861.jpg',
#  '../../../../cds-vis-data/flowers/image_0862.jpg',
#  '../../../../cds-vis-data/flowers/image_0863.jpg',
#  '../../../../cds-vis-data/flowers/image_0864.jpg',
#  '../../../../cds-vis-data/flowers/image_0865.jpg',
#  '../../../../cds-vis-data/flowers/image_0866.jpg',
#  '../../../../cds-vis-data/flowers/image_0867.jpg',
#  '../../../../cds-vis-data/flowers/image_0868.jpg',
#  '../../../../cds-vis-data/flowers/image_0869.jpg',
#  '../../../../cds-vis-data/flowers/image_0870.jpg',
#  '../../../../cds-vis-data/flowers/image_0871.jpg',
#  '../../../../cds-vis-data/flowers/image_0872.jpg',
#  '../../../../cds-vis-data/flowers/image_0873.jpg',
#  '../../../../cds-vis-data/flowers/image_0874.jpg',
#  '../../../../cds-vis-data/flowers/image_0875.jpg',
#  '../../../../cds-vis-data/flowers/image_0876.jpg',
#  '../../../../cds-vis-data/flowers/image_0877.jpg',
#  '../../../../cds-vis-data/flowers/image_0878.jpg',
#  '../../../../cds-vis-data/flowers/image_0879.jpg',
#  '../../../../cds-vis-data/flowers/image_0880.jpg',
#  '../../../../cds-vis-data/flowers/image_0881.jpg',
#  '../../../../cds-vis-data/flowers/image_0882.jpg',
#  '../../../../cds-vis-data/flowers/image_0883.jpg',
#  '../../../../cds-vis-data/flowers/image_0884.jpg',
#  '../../../../cds-vis-data/flowers/image_0885.jpg',
#  '../../../../cds-vis-data/flowers/image_0886.jpg',
#  '../../../../cds-vis-data/flowers/image_0887.jpg',
#  '../../../../cds-vis-data/flowers/image_0888.jpg',
#  '../../../../cds-vis-data/flowers/image_0889.jpg',
#  '../../../../cds-vis-data/flowers/image_0890.jpg',
#  '../../../../cds-vis-data/flowers/image_0891.jpg',
#  '../../../../cds-vis-data/flowers/image_0892.jpg',
#  '../../../../cds-vis-data/flowers/image_0893.jpg',
#  '../../../../cds-vis-data/flowers/image_0894.jpg',
#  '../../../../cds-vis-data/flowers/image_0895.jpg',
#  '../../../../cds-vis-data/flowers/image_0896.jpg',
#  '../../../../cds-vis-data/flowers/image_0897.jpg',
#  '../../../../cds-vis-data/flowers/image_0898.jpg',
#  '../../../../cds-vis-data/flowers/image_0899.jpg',
#  '../../../../cds-vis-data/flowers/image_0900.jpg',
#  '../../../../cds-vis-data/flowers/image_0901.jpg',
#  '../../../../cds-vis-data/flowers/image_0902.jpg',
#  '../../../../cds-vis-data/flowers/image_0903.jpg',
#  '../../../../cds-vis-data/flowers/image_0904.jpg',
#  '../../../../cds-vis-data/flowers/image_0905.jpg',
#  '../../../../cds-vis-data/flowers/image_0906.jpg',
#  '../../../../cds-vis-data/flowers/image_0907.jpg',
#  '../../../../cds-vis-data/flowers/image_0908.jpg',
#  '../../../../cds-vis-data/flowers/image_0909.jpg',
#  '../../../../cds-vis-data/flowers/image_0910.jpg',
#  '../../../../cds-vis-data/flowers/image_0911.jpg',
#  '../../../../cds-vis-data/flowers/image_0912.jpg',
#  '../../../../cds-vis-data/flowers/image_0913.jpg',
#  '../../../../cds-vis-data/flowers/image_0914.jpg',
#  '../../../../cds-vis-data/flowers/image_0915.jpg',
#  '../../../../cds-vis-data/flowers/image_0916.jpg',
#  '../../../../cds-vis-data/flowers/image_0917.jpg',
#  '../../../../cds-vis-data/flowers/image_0918.jpg',
#  '../../../../cds-vis-data/flowers/image_0919.jpg',
#  '../../../../cds-vis-data/flowers/image_0920.jpg',
#  '../../../../cds-vis-data/flowers/image_0921.jpg',
#  '../../../../cds-vis-data/flowers/image_0922.jpg',
#  '../../../../cds-vis-data/flowers/image_0923.jpg',
#  '../../../../cds-vis-data/flowers/image_0924.jpg',
#  '../../../../cds-vis-data/flowers/image_0925.jpg',
#  '../../../../cds-vis-data/flowers/image_0926.jpg',
#  '../../../../cds-vis-data/flowers/image_0927.jpg',
#  '../../../../cds-vis-data/flowers/image_0928.jpg',
#  '../../../../cds-vis-data/flowers/image_0929.jpg',
#  '../../../../cds-vis-data/flowers/image_0930.jpg',
#  '../../../../cds-vis-data/flowers/image_0931.jpg',
#  '../../../../cds-vis-data/flowers/image_0932.jpg',
#  '../../../../cds-vis-data/flowers/image_0933.jpg',
#  '../../../../cds-vis-data/flowers/image_0934.jpg',
#  '../../../../cds-vis-data/flowers/image_0935.jpg',
#  '../../../../cds-vis-data/flowers/image_0936.jpg',
#  '../../../../cds-vis-data/flowers/image_0937.jpg',
#  '../../../../cds-vis-data/flowers/image_0938.jpg',
#  '../../../../cds-vis-data/flowers/image_0939.jpg',
#  '../../../../cds-vis-data/flowers/image_0940.jpg',
#  '../../../../cds-vis-data/flowers/image_0941.jpg',
#  '../../../../cds-vis-data/flowers/image_0942.jpg',
#  '../../../../cds-vis-data/flowers/image_0943.jpg',
#  '../../../../cds-vis-data/flowers/image_0944.jpg',
#  '../../../../cds-vis-data/flowers/image_0945.jpg',
#  '../../../../cds-vis-data/flowers/image_0946.jpg',
#  '../../../../cds-vis-data/flowers/image_0947.jpg',
#  '../../../../cds-vis-data/flowers/image_0948.jpg',
#  '../../../../cds-vis-data/flowers/image_0949.jpg',
#  '../../../../cds-vis-data/flowers/image_0950.jpg',
#  '../../../../cds-vis-data/flowers/image_0951.jpg',
#  '../../../../cds-vis-data/flowers/image_0952.jpg',
#  '../../../../cds-vis-data/flowers/image_0953.jpg',
#  '../../../../cds-vis-data/flowers/image_0954.jpg',
#  '../../../../cds-vis-data/flowers/image_0955.jpg',
#  '../../../../cds-vis-data/flowers/image_0956.jpg',
#  '../../../../cds-vis-data/flowers/image_0957.jpg',
#  '../../../../cds-vis-data/flowers/image_0958.jpg',
#  '../../../../cds-vis-data/flowers/image_0959.jpg',
#  '../../../../cds-vis-data/flowers/image_0960.jpg',
#  '../../../../cds-vis-data/flowers/image_0961.jpg',
#  '../../../../cds-vis-data/flowers/image_0962.jpg',
#  '../../../../cds-vis-data/flowers/image_0963.jpg',
#  '../../../../cds-vis-data/flowers/image_0964.jpg',
#  '../../../../cds-vis-data/flowers/image_0965.jpg',
#  '../../../../cds-vis-data/flowers/image_0966.jpg',
#  '../../../../cds-vis-data/flowers/image_0967.jpg',
#  '../../../../cds-vis-data/flowers/image_0968.jpg',
#  '../../../../cds-vis-data/flowers/image_0969.jpg',
#  '../../../../cds-vis-data/flowers/image_0970.jpg',
#  '../../../../cds-vis-data/flowers/image_0971.jpg',
#  '../../../../cds-vis-data/flowers/image_0972.jpg',
#  '../../../../cds-vis-data/flowers/image_0973.jpg',
#  '../../../../cds-vis-data/flowers/image_0974.jpg',
#  '../../../../cds-vis-data/flowers/image_0975.jpg',
#  '../../../../cds-vis-data/flowers/image_0976.jpg',
#  '../../../../cds-vis-data/flowers/image_0977.jpg',
#  '../../../../cds-vis-data/flowers/image_0978.jpg',
#  '../../../../cds-vis-data/flowers/image_0979.jpg',
#  '../../../../cds-vis-data/flowers/image_0980.jpg',
#  '../../../../cds-vis-data/flowers/image_0981.jpg',
#  '../../../../cds-vis-data/flowers/image_0982.jpg',
#  '../../../../cds-vis-data/flowers/image_0983.jpg',
#  '../../../../cds-vis-data/flowers/image_0984.jpg',
#  '../../../../cds-vis-data/flowers/image_0985.jpg',
#  '../../../../cds-vis-data/flowers/image_0986.jpg',
#  '../../../../cds-vis-data/flowers/image_0987.jpg',
#  '../../../../cds-vis-data/flowers/image_0988.jpg',
#  '../../../../cds-vis-data/flowers/image_0989.jpg',
#  '../../../../cds-vis-data/flowers/image_0990.jpg',
#  '../../../../cds-vis-data/flowers/image_0991.jpg',
#  '../../../../cds-vis-data/flowers/image_0992.jpg',
#  '../../../../cds-vis-data/flowers/image_0993.jpg',
#  '../../../../cds-vis-data/flowers/image_0994.jpg',
#  '../../../../cds-vis-data/flowers/image_0995.jpg',
#  '../../../../cds-vis-data/flowers/image_0996.jpg',
#  '../../../../cds-vis-data/flowers/image_0997.jpg',
#  '../../../../cds-vis-data/flowers/image_0998.jpg',
#  '../../../../cds-vis-data/flowers/image_0999.jpg',
#  '../../../../cds-vis-data/flowers/image_1000.jpg',
#  ...]

# %%
feature_list = []
# iterate over all files with a progress bar
for i in notebook.tqdm(range(len(filenames))):
    feature_list.append(extract_features(filenames[i], model))
# Out:
#   0%|          | 0/1360 [00:00<?, ?it/s]

# %% [markdown]
# ## Nearest neighbours

# %% [markdown]
# Once we have our *database* of extracted embeddings, we can then use K-Nearest Neighbours to find similar images.

# %%
from sklearn.neighbors import NearestNeighbors
neighbors = NearestNeighbors(n_neighbors=10, 
                             algorithm='brute', # using brute force by calculate the cosine similarity to every other image in the dataset. is fine because we have a relatively small dataset
                             metric='cosine').fit(feature_list)

# %% [markdown]
# __Calculate nearest neighbours for target__

# %%
distances, indices = neighbors.kneighbors([feature_list[0]])

# %% [markdown]
# __Save indices, print data__

# %%
idxs = []
for i in range(1,6):
    print(distances[0][i], indices[0][i])
    idxs.append(indices[0][i])
# Out:
# 0.13251859 36
# 0.13901675 15
# 0.16058844 35
# 0.16243184 16
# 0.16392565 48

# %% [markdown]
# __Plot target image__

# %%
plt.imshow(mpimg.imread(filenames[0]))

# %% [markdown]
# __Plot close images__

# %%
plt.imshow(mpimg.imread(filenames[249]))

# %% [markdown]
# __Plot target and top 3 closest together__

# %%
# plt target
plt.imshow(mpimg.imread(filenames[1000]))

# plot 3 most similar
f, axarr = plt.subplots(1,3)
axarr[0].imshow(mpimg.imread(filenames[idxs[0]]))
axarr[1].imshow(mpimg.imread(filenames[idxs[1]]))
axarr[2].imshow(mpimg.imread(filenames[idxs[2]]))

# %% [markdown]
# ## Simple style transfer

# %% [markdown]
# __Load a quick style transfer model from TF Hub__
#
# You can find more details [here](https://www.tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization).
#
# You can also play around with an interactive version with the same model at [this website](https://reiinakano.com/arbitrary-image-stylization-tfjs/).

# %%
from utils.styletransfer import st_load, show_n
# Load TF-Hub module.
hub_handle = 'https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2'
hub_module = hub.load(hub_handle)

# %% [markdown]
# __Load the content image and the style image__

# %%
content_image = st_load(os.path.join("..", "..", "..", "..", "cds-vis-data", "data", "img", "florence.jpg"))
style_image = st_load(os.path.join("..", "..", "..", "..", "cds-vis-data", "data", "img", "starry_night.jpg"))

# %% [markdown]
# __Process using the model__

# %%
outputs = hub_module(content_image, style_image)
stylized_image = outputs[0]

# %% [markdown]
# __Show content, style, and stylized image__

# %%
show_n([content_image, style_image, stylized_image], 
       titles=['Original content image', 'Style image', 'Stylized image'])

# %% [markdown]
# ### Tasks
#
# - Take the code in this notebook and turn it into a Python script. You can then add this to the repo for your Assignment 1 solution for creating doing image search
#   - I.e. your Assignment 1 repo would contain both code for image search using colour histograms *and* for image search using a pretrained CNN.
